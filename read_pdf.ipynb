# %%
import pdfplumber
import pandas as pd

def extract_table_data(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        page = pdf.pages[0]  # Giả sử bảng bạn muốn trích xuất ở trang đầu tiên
        tables = page.extract_tables()

        if tables:
            df = pd.DataFrame(tables[0], columns=['Ngày GD/TNX Date', 'Số tiền ghi nợ/Debit', 'Số tiền ghi có/Credit', 'Số Dư', 'Nội dung chi tiết/Transactions in detail'])
            return df
        else:
            return None

# Thay thế 'your_file.pdf' bằng đường dẫn đến file PDF của bạn
df = extract_table_data('thong_tin_ung_ho_qua_tsk_vcb_0011001932418_tu_01_09_den10_09_2024.pdf')

if df is not None:
    print(df)
# Out:
#                                     Ngày GD/TNX Date    Số tiền ghi nợ/Debit
# 0                  Ngày GD/\nTNX Date\nSố CT/ Doc No  Số tiền ghi nợ/\nDebit  \
# 1  01/09/2024\n5213.45946\n01/09/2024\n5090.85797...
#
#                                Số tiền ghi có/Credit            Số Dư
# 0                            Số tiền ghi có/\nCredit  Số dư/\nBalance  \
# 1  50.000\n20.000\n29.000\n3.000\n3.000\n3.000\n3...
#
#             Nội dung chi tiết/Transactions in detail
# 0         Nội dung chi tiết/\nTransactions in detail
# 1  292976.010924.013647.xin cam on\nVCB.CTDK.31/0...

# %% [markdown]
# # Dùng tabula để đọc pdf

# %%
import pandas as pd
import tabula

# %%
# # Set display options to show all columns and rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', None)     # Show all rows
# pd.set_option('display.max_colwidth', None) # Show full column width

# %%
dfs = tabula.read_pdf('thong_tin_ung_ho_qua_tsk_vcb_0011001932418_tu_01_09_den10_09_2024.pdf', pages=1, relative_area=True, relative_columns=True)

# %%
df = dfs[0]
df
# Out:
#                    Ngày GD/\rTNX Date\rSố CT/ Doc No  Số tiền ghi nợ/\rDebit
# 0  01/09/2024\r5213.45946\r01/09/2024\r5090.85797...                     NaN  \
#
#                              Số tiền ghi có/\rCredit  Số dư/\rBalance
# 0  50.000\r20.000\r29.000\r3.000\r3.000\r3.000\r3...              NaN  \
#
#           Nội dung chi tiết/\rTransactions in detail
# 0  292976.010924.013647.xin cam on\rVCB.CTDK.31/0...

# %%
import tabula

# Đọc PDF với tham số stream
dfs = tabula.read_pdf('thong_tin_ung_ho_qua_tsk_vcb_0011001932418_tu_01_09_den10_09_2024.pdf', pages=1, stream=True, relative_area=True, relative_columns=True)


# Lấy DataFrame đầu tiên
df = dfs[0]

# df = df.replace(to_replace=r'\r', value=' ', regex=True)

# Hiển thị DataFrame đã xử lý
df
# Out:
#          Ngày GD/       Unnamed: 0       Unnamed: 1 Unnamed: 2
# 0             NaN  Số tiền ghi nợ/  Số tiền ghi có/     Số dư/  \
# 1        TNX Date              NaN              NaN        NaN
# 2             NaN            Debit           Credit    Balance
# 3   Số CT/ Doc No              NaN              NaN        NaN
# 4      01/09/2024              NaN              NaN        NaN
# 5             NaN              NaN           50.000        NaN
# 6      5213.45946              NaN              NaN        NaN
# 7      01/09/2024              NaN              NaN        NaN
# 8             NaN              NaN           20.000        NaN
# 9      5090.85797              NaN              NaN        NaN
# 10            NaN              NaN              NaN        NaN
# 11            NaN              NaN              NaN        NaN
# 12     01/09/2024              NaN              NaN        NaN
# 13            NaN              NaN           29.000        NaN
# 14     5241.83107              NaN              NaN        NaN
# 15            NaN              NaN              NaN        NaN
# 16            NaN              NaN              NaN        NaN
# 17            NaN              NaN              NaN        NaN
# 18     01/09/2024              NaN              NaN        NaN
# 19            NaN              NaN            3.000        NaN
# 20     5218.87149              NaN              NaN        NaN
# 21            NaN              NaN              NaN        NaN
# 22     01/09/2024              NaN              NaN        NaN
# 23            NaN              NaN            3.000        NaN
# 24     5388.96713              NaN              NaN        NaN
# 25            NaN              NaN              NaN        NaN
# 26            NaN              NaN              NaN        NaN
# 27     01/09/2024              NaN              NaN        NaN
# 28            NaN              NaN            3.000        NaN
# 29     5212.91607              NaN              NaN        NaN
# 30            NaN              NaN              NaN        NaN
# 31     01/09/2024              NaN              NaN        NaN
# 32            NaN              NaN            3.000        NaN
# 33     5220.28596              NaN              NaN        NaN
# 34            NaN              NaN              NaN        NaN
# 35     01/09/2024              NaN              NaN        NaN
# 36            NaN              NaN            3.000        NaN
# 37     5388.33462              NaN              NaN        NaN
# 38            NaN              NaN              NaN        NaN
# 39            NaN              NaN              NaN        NaN
# 40     01/09/2024              NaN              NaN        NaN
# 41            NaN              NaN            3.000        NaN
# 42     5216.68569              NaN              NaN        NaN
# 43            NaN              NaN              NaN        NaN
# 44     01/09/2024              NaN              NaN        NaN
# 45            NaN              NaN            3.000        NaN
# 46     5387.37142              NaN              NaN        NaN
# 47            NaN              NaN              NaN        NaN
# 48            NaN              NaN              NaN        NaN
# 49     01/09/2024              NaN              NaN        NaN
# 50            NaN              NaN           10.000        NaN
# 51     5161.94345              NaN              NaN        NaN
# 52            NaN              NaN              NaN        NaN
# 53            NaN              NaN              NaN        NaN
# 54     01/09/2024              NaN              NaN        NaN
# 55            NaN              NaN            6.000        NaN
# 56     5219.94264              NaN              NaN        NaN
# 57            NaN              NaN              NaN        NaN
#
#                                   Unnamed: 3
# 0                         Nội dung chi tiết/
# 1                                        NaN
# 2                     Transactions in detail
# 3                                        NaN
# 4                                        NaN
# 5            292976.010924.013647.xin cam on
# 6                                        NaN
# 7                                        NaN
# 8      VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu
# 9                                        NaN
# 10       0481000755821 toi 0011001932418 MAT
# 11          TRAN TO QUOC VN - BAN CUU TRO TW
# 12                                       NaN
# 13            MBVCB.6916176124.CAO VIET TUAN
# 14                                       NaN
# 15  chuyen tien.CT tu 0101001222009 CAO VIET
# 16        TUAN toi 0011001932418 MAT TRAN TO
# 17                  QUOC VN - BAN CUU TRO TW
# 18                                       NaN
# 19    272986.010924.101858.DO DUC LOI chuyen
# 20                                       NaN
# 21                                      tien
# 22                                       NaN
# 23  020097040509011046122024JDC5013867.96713
# 24                                       NaN
# 25    .104607.Vietcombank:0011001932418:DANG
# 26                      THI THANH  MHS533583
# 27                                       NaN
# 28   529474.010924.112032.BUI VAN DAI chuyen
# 29                                       NaN
# 30                                      tien
# 31                                       NaN
# 32       577301.010924.113215.DO DUC LOI MHS
# 33                                       NaN
# 34                                      4242
# 35                                       NaN
# 36  020097040509011137472024Y7ZE058213.33462
# 37                                       NaN
# 38   .113747.Vietcombank:0011001932418:NGUYE
# 39                     N THI VAN chuyen tien
# 40                                       NaN
# 41      761664.010924.121847.NGUYEN VAN TUAN
# 42                                       NaN
# 43                               chuyen tien
# 44                                       NaN
# 45   0200970405090112202020246WVI059470.3714
# 46                                       NaN
# 47  2.122015.Vietcombank:0011001932418:NGUYE
# 48                        N QUANG THO 010166
# 49                                       NaN
# 50        PARTNER.DIRECT_DEBITS_VCB.ZLP.ZP6R
# 51                                       NaN
# 52  34H953F5.20240901.Nguyet chuyen tien qua
# 53                                   Zalopay
# 54                                       NaN
# 55       266303.010924.122804.NGUYEN THI MAO
# 56                                       NaN
# 57                               Chuyen tien

# %% [markdown]
# # Xư lý data

# %%
# Giả sử df là DataFrame mà bạn đã có
# Khởi tạo danh sách lớn để chứa các mảng con
result_arrays = []
current_array = []

# Lặp qua từng hàng trong DataFrame
for index, row in df.iterrows():
    # Kiểm tra xem cột đầu tiên có phải là ngày tháng hay không
    if pd.to_datetime(row[0], errors='coerce', format='%d/%m/%Y') is not pd.NaT:
        # Nếu có, kiểm tra xem current_array có dữ liệu không
        if current_array:
            result_arrays.append(current_array)  # Thêm mảng hiện tại vào danh sách lớn
            current_array = []  # Reset current_array cho mảng mới
        
    # Thêm hàng vào current_array
    current_array.append(row.values)

# Thêm mảng cuối cùng nếu nó không rỗng
if current_array:
    result_arrays.append(current_array)

# Hiển thị kết quả
for array in result_arrays:
    print(array)
    print('-' * 70)  # Dòng phân cách giữa các mảng con
# Out:
# [array([nan, 'Số tiền ghi nợ/', 'Số tiền ghi có/', 'Số dư/',
#        'Nội dung chi tiết/'], dtype=object), array(['TNX Date', nan, nan, nan, nan], dtype=object), array([nan, 'Debit', 'Credit', 'Balance', 'Transactions in detail'],
#       dtype=object), array(['Số CT/ Doc No', nan, nan, nan, nan], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '50.000', nan, '292976.010924.013647.xin cam on'],
#       dtype=object), array(['5213.45946', nan, nan, nan, nan], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '20.000', nan, 'VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu'],
#       dtype=object), array(['5090.85797', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, '0481000755821 toi 0011001932418 MAT'],
#       dtype=object), array([nan, nan, nan, nan, 'TRAN TO QUOC VN - BAN CUU TRO TW'],
#       dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '29.000', nan, 'MBVCB.6916176124.CAO VIET TUAN'],
#       dtype=object), array(['5241.83107', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, 'chuyen tien.CT tu 0101001222009 CAO VIET'],
#       dtype=object), array([nan, nan, nan, nan, 'TUAN toi 0011001932418 MAT TRAN TO'],
#       dtype=object), array([nan, nan, nan, nan, 'QUOC VN - BAN CUU TRO TW'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '3.000', nan, '272986.010924.101858.DO DUC LOI chuyen'],
#       dtype=object), array(['5218.87149', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, 'tien'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '3.000', nan, '020097040509011046122024JDC5013867.96713'],
#       dtype=object), array(['5388.96713', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, '.104607.Vietcombank:0011001932418:DANG'],
#       dtype=object), array([nan, nan, nan, nan, 'THI THANH  MHS533583'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '3.000', nan, '529474.010924.112032.BUI VAN DAI chuyen'],
#       dtype=object), array(['5212.91607', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, 'tien'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '3.000', nan, '577301.010924.113215.DO DUC LOI MHS'],
#       dtype=object), array(['5220.28596', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, '4242'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '3.000', nan, '020097040509011137472024Y7ZE058213.33462'],
#       dtype=object), array(['5388.33462', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, '.113747.Vietcombank:0011001932418:NGUYE'],
#       dtype=object), array([nan, nan, nan, nan, 'N THI VAN chuyen tien'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '3.000', nan, '761664.010924.121847.NGUYEN VAN TUAN'],
#       dtype=object), array(['5216.68569', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, 'chuyen tien'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '3.000', nan, '0200970405090112202020246WVI059470.3714'],
#       dtype=object), array(['5387.37142', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, '2.122015.Vietcombank:0011001932418:NGUYE'],
#       dtype=object), array([nan, nan, nan, nan, 'N QUANG THO 010166'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '10.000', nan, 'PARTNER.DIRECT_DEBITS_VCB.ZLP.ZP6R'],
#       dtype=object), array(['5161.94345', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, '34H953F5.20240901.Nguyet chuyen tien qua'],
#       dtype=object), array([nan, nan, nan, nan, 'Zalopay'], dtype=object)]
# ----------------------------------------------------------------------
# [array(['01/09/2024', nan, nan, nan, nan], dtype=object), array([nan, nan, '6.000', nan, '266303.010924.122804.NGUYEN THI MAO'],
#       dtype=object), array(['5219.94264', nan, nan, nan, nan], dtype=object), array([nan, nan, nan, nan, 'Chuyen tien'], dtype=object)]
# ----------------------------------------------------------------------

# %%
dictionaries = []
for array in result_arrays:
    # Kiểm tra xem có phải là mảng tiêu đề hay không
    if array[0][0] == 'TNX Date':
        continue  # Bỏ qua mảng tiêu đề

    # Lấy dữ liệu cần thiết
    date = array[0][0]
    transaction_id = array[2][0]
    amount = array[1][2]
    content = ""
    for row in array:
        content += str(row[4]) + " "

    # Tạo dictionary
    dictionary = {'Date': date, 'TransactionID': transaction_id, 'Amount': amount, 'Content': content.strip()}
    dictionaries.append(dictionary)

# In kết quả
for dictionary in dictionaries:
    print(dictionary)
# Out:
# {'Date': nan, 'TransactionID': nan, 'Amount': nan, 'Content': 'Nội dung chi tiết/ nan Transactions in detail nan'}
# {'Date': '01/09/2024', 'TransactionID': '5213.45946', 'Amount': '50.000', 'Content': 'nan 292976.010924.013647.xin cam on nan'}
# {'Date': '01/09/2024', 'TransactionID': '5090.85797', 'Amount': '20.000', 'Content': 'nan VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu nan 0481000755821 toi 0011001932418 MAT TRAN TO QUOC VN - BAN CUU TRO TW'}
# {'Date': '01/09/2024', 'TransactionID': '5241.83107', 'Amount': '29.000', 'Content': 'nan MBVCB.6916176124.CAO VIET TUAN nan chuyen tien.CT tu 0101001222009 CAO VIET TUAN toi 0011001932418 MAT TRAN TO QUOC VN - BAN CUU TRO TW'}
# {'Date': '01/09/2024', 'TransactionID': '5218.87149', 'Amount': '3.000', 'Content': 'nan 272986.010924.101858.DO DUC LOI chuyen nan tien'}
# {'Date': '01/09/2024', 'TransactionID': '5388.96713', 'Amount': '3.000', 'Content': 'nan 020097040509011046122024JDC5013867.96713 nan .104607.Vietcombank:0011001932418:DANG THI THANH  MHS533583'}
# {'Date': '01/09/2024', 'TransactionID': '5212.91607', 'Amount': '3.000', 'Content': 'nan 529474.010924.112032.BUI VAN DAI chuyen nan tien'}
# {'Date': '01/09/2024', 'TransactionID': '5220.28596', 'Amount': '3.000', 'Content': 'nan 577301.010924.113215.DO DUC LOI MHS nan 4242'}
# {'Date': '01/09/2024', 'TransactionID': '5388.33462', 'Amount': '3.000', 'Content': 'nan 020097040509011137472024Y7ZE058213.33462 nan .113747.Vietcombank:0011001932418:NGUYE N THI VAN chuyen tien'}
# {'Date': '01/09/2024', 'TransactionID': '5216.68569', 'Amount': '3.000', 'Content': 'nan 761664.010924.121847.NGUYEN VAN TUAN nan chuyen tien'}
# {'Date': '01/09/2024', 'TransactionID': '5387.37142', 'Amount': '3.000', 'Content': 'nan 0200970405090112202020246WVI059470.3714 nan 2.122015.Vietcombank:0011001932418:NGUYE N QUANG THO 010166'}
# {'Date': '01/09/2024', 'TransactionID': '5161.94345', 'Amount': '10.000', 'Content': 'nan PARTNER.DIRECT_DEBITS_VCB.ZLP.ZP6R nan 34H953F5.20240901.Nguyet chuyen tien qua Zalopay'}
# {'Date': '01/09/2024', 'TransactionID': '5219.94264', 'Amount': '6.000', 'Content': 'nan 266303.010924.122804.NGUYEN THI MAO nan Chuyen tien'}

# %%
cleaned_dictionaries = []
for dictionary in dictionaries:
    # Kiểm tra xem Date có phải là ngày hợp lệ không
    if pd.to_datetime(dictionary['Date'], errors='coerce', format='%d/%m/%Y') is not pd.NaT:
        # Làm sạch Content: loại bỏ nan và khoảng trắng dư thừa
        cleaned_content = ' '.join(filter(lambda x: x.strip() != '' and x.strip().lower() != 'nan', dictionary['Content'].split()))
        
        # Cập nhật nội dung đã làm sạch vào dictionary
        dictionary['Content'] = cleaned_content
        
        # Thêm vào danh sách cleaned_dictionaries nếu Content không rỗng
        if cleaned_content:
            cleaned_dictionaries.append(dictionary)

# Hiển thị kết quả cuối cùng
for d in cleaned_dictionaries:
    print(d)
# Out:
# {'Date': '01/09/2024', 'TransactionID': '5213.45946', 'Amount': '50.000', 'Content': '292976.010924.013647.xin cam on'}
# {'Date': '01/09/2024', 'TransactionID': '5090.85797', 'Amount': '20.000', 'Content': 'VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu 0481000755821 toi 0011001932418 MAT TRAN TO QUOC VN - BAN CUU TRO TW'}
# {'Date': '01/09/2024', 'TransactionID': '5241.83107', 'Amount': '29.000', 'Content': 'MBVCB.6916176124.CAO VIET TUAN chuyen tien.CT tu 0101001222009 CAO VIET TUAN toi 0011001932418 MAT TRAN TO QUOC VN - BAN CUU TRO TW'}
# {'Date': '01/09/2024', 'TransactionID': '5218.87149', 'Amount': '3.000', 'Content': '272986.010924.101858.DO DUC LOI chuyen tien'}
# {'Date': '01/09/2024', 'TransactionID': '5388.96713', 'Amount': '3.000', 'Content': '020097040509011046122024JDC5013867.96713 .104607.Vietcombank:0011001932418:DANG THI THANH MHS533583'}
# {'Date': '01/09/2024', 'TransactionID': '5212.91607', 'Amount': '3.000', 'Content': '529474.010924.112032.BUI VAN DAI chuyen tien'}
# {'Date': '01/09/2024', 'TransactionID': '5220.28596', 'Amount': '3.000', 'Content': '577301.010924.113215.DO DUC LOI MHS 4242'}
# {'Date': '01/09/2024', 'TransactionID': '5388.33462', 'Amount': '3.000', 'Content': '020097040509011137472024Y7ZE058213.33462 .113747.Vietcombank:0011001932418:NGUYE N THI VAN chuyen tien'}
# {'Date': '01/09/2024', 'TransactionID': '5216.68569', 'Amount': '3.000', 'Content': '761664.010924.121847.NGUYEN VAN TUAN chuyen tien'}
# {'Date': '01/09/2024', 'TransactionID': '5387.37142', 'Amount': '3.000', 'Content': '0200970405090112202020246WVI059470.3714 2.122015.Vietcombank:0011001932418:NGUYE N QUANG THO 010166'}
# {'Date': '01/09/2024', 'TransactionID': '5161.94345', 'Amount': '10.000', 'Content': 'PARTNER.DIRECT_DEBITS_VCB.ZLP.ZP6R 34H953F5.20240901.Nguyet chuyen tien qua Zalopay'}
# {'Date': '01/09/2024', 'TransactionID': '5219.94264', 'Amount': '6.000', 'Content': '266303.010924.122804.NGUYEN THI MAO Chuyen tien'}

# %%
import pandas as pd
import tabula

# Đọc tất cả các trang từ PDF
## Tất cả pages
# dfs = tabula.read_pdf('thong_tin_ung_ho_qua_tsk_vcb_0011001932418_tu_01_09_den10_09_2024.pdf', pages='all', stream=True, relative_area=True, relative_columns=True)

## Với 3 pages đầu
dfs = tabula.read_pdf('thong_tin_ung_ho_qua_tsk_vcb_0011001932418_tu_01_09_den10_09_2024.pdf', pages='1-3', stream=True, relative_area=True, relative_columns=True)

# Kết hợp tất cả DataFrames vào một DataFrame duy nhất
df = pd.concat(dfs, ignore_index=True)

result_arrays = []
current_array = []

# Lặp qua từng hàng trong DataFrame
for index, row in df.iterrows():
    # Kiểm tra xem cột đầu tiên có phải là ngày tháng hay không
    if pd.to_datetime(row[0], errors='coerce', format='%d/%m/%Y') is not pd.NaT:
        # Nếu có, kiểm tra xem current_array có dữ liệu không
        if current_array:
            result_arrays.append(current_array)  # Thêm mảng hiện tại vào danh sách lớn
            current_array = []  # Reset current_array cho mảng mới
        
    # Thêm hàng vào current_array
    current_array.append(row.values)

# Thêm mảng cuối cùng nếu nó không rỗng
if current_array:
    result_arrays.append(current_array)

dictionaries = []
for array in result_arrays:
    # Kiểm tra xem có phải là mảng tiêu đề hay không
    if array[0][0] == 'TNX Date':
        continue  # Bỏ qua mảng tiêu đề

    # Lấy dữ liệu cần thiết
    date = array[0][0]
    transaction_id = array[2][0]
    amount = array[1][2]
    content = ""
    for row in array:
        content += str(row[4]) + " "

    # Tạo dictionary
    dictionary = {'Date': date, 'TransactionID': transaction_id, 'Amount': amount, 'Content': content.strip()}
    dictionaries.append(dictionary)

cleaned_dictionaries = []
for dictionary in dictionaries:
    # Kiểm tra xem Date có phải là ngày hợp lệ không
    if pd.to_datetime(dictionary['Date'], errors='coerce', format='%d/%m/%Y') is not pd.NaT:
        # Làm sạch Content: loại bỏ nan và khoảng trắng dư thừa
        cleaned_content = ' '.join(filter(lambda x: x.strip() != '' and x.strip().lower() != 'nan', dictionary['Content'].split()))
        
        # Cập nhật nội dung đã làm sạch vào dictionary
        dictionary['Content'] = cleaned_content
        
        # Thêm vào danh sách cleaned_dictionaries nếu Content không rỗng
        if cleaned_content:
            cleaned_dictionaries.append(dictionary)

# Kết quả cuối cùng
print(cleaned_dictionaries)
# Out:
# [{'Date': '01/09/2024', 'TransactionID': '5213.45946', 'Amount': '50.000', 'Content': '292976.010924.013647.xin cam on'}, {'Date': '01/09/2024', 'TransactionID': '5090.85797', 'Amount': '20.000', 'Content': 'VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu 0481000755821 toi 0011001932418 MAT TRAN TO QUOC VN - BAN CUU TRO TW'}, {'Date': '01/09/2024', 'TransactionID': '5241.83107', 'Amount': '29.000', 'Content': 'MBVCB.6916176124.CAO VIET TUAN chuyen tien.CT tu 0101001222009 CAO VIET TUAN toi 0011001932418 MAT TRAN TO QUOC VN - BAN CUU TRO TW'}, {'Date': '01/09/2024', 'TransactionID': '5218.87149', 'Amount': '3.000', 'Content': '272986.010924.101858.DO DUC LOI chuyen tien'}, {'Date': '01/09/2024', 'TransactionID': '5388.96713', 'Amount': '3.000', 'Content': '020097040509011046122024JDC5013867.96713 .104607.Vietcombank:0011001932418:DANG THI THANH MHS533583'}, {'Date': '01/09/2024', 'TransactionID': '5212.91607', 'Amount': '3.000', 'Content': '529474.010924.112032.BUI VAN DAI chuyen tien'}, {'Date': '01/09/2024', 'TransactionID': '5220.28596', 'Amount': '3.000', 'Content': '577301.010924.113215.DO DUC LOI MHS 4242'}, {'Date': '01/09/2024', 'TransactionID': '5388.33462', 'Amount': '3.000', 'Content': '020097040509011137472024Y7ZE058213.33462 .113747.Vietcombank:0011001932418:NGUYE N THI VAN chuyen tien'}, {'Date': '01/09/2024', 'TransactionID': '5216.68569', 'Amount': '3.000', 'Content': '761664.010924.121847.NGUYEN VAN TUAN chuyen tien'}, {'Date': '01/09/2024', 'TransactionID': '5387.37142', 'Amount': '3.000', 'Content': '0200970405090112202020246WVI059470.3714 2.122015.Vietcombank:0011001932418:NGUYE N QUANG THO 010166'}, {'Date': '01/09/2024', 'TransactionID': '5161.94345', 'Amount': '10.000', 'Content': 'PARTNER.DIRECT_DEBITS_VCB.ZLP.ZP6R 34H953F5.20240901.Nguyet chuyen tien qua Zalopay'}, {'Date': '01/09/2024', 'TransactionID': '5219.94264', 'Amount': '6.000', 'Content': '266303.010924.122804.NGUYEN THI MAO Chuyen tien Nội dung chi tiết/ Transactions in detail'}, {'Date': '01/09/2024', 'TransactionID': '5215.97152', 'Amount': '3.000', 'Content': '267515.010924.122904.NGUYEN THI MAO Chuyen tien'}, {'Date': '01/09/2024', 'TransactionID': '5219.24714', 'Amount': '10.000', 'Content': '018806.010924.213139.chuc mung ngay 29 nuoc cong hoa xa hoi chu nghia Viet Nam'}, {'Date': '02/09/2024', 'TransactionID': '5212.22965', 'Amount': '10.000', 'Content': '055464.020924.064157.Ung Ho Nha Nuoc Viet Nam Va Giup do Nguoi dan (by TPBank ChatPay)'}, {'Date': '02/09/2024', 'TransactionID': '5245.21394', 'Amount': '10.000', 'Content': 'MBVCB.6924605040.gia dinh Dung Thuy Giang chuc to quoc khoe manh, binh an, hanh phuc, thinh vuong, cam on.CT tu 1018144916 HOANG THANH THUY toi 0011001932418 MAT TRAN TO QUOC VN - BAN CUU TRO TW'}, {'Date': '02/09/2024', 'TransactionID': '5078.73943', 'Amount': '50.000', 'Content': 'MBVCB.6925071164.mung ngay quoc khanh.CT tu 1028808193 toi 0011001932418 Uy Ban Trung uong Mat tran To quoc Viet Nam'}, {'Date': '02/09/2024', 'TransactionID': '5216.8149', 'Amount': '2.000', 'Content': '524322.020924.175952.2091945'}, {'Date': '02/09/2024', 'TransactionID': '5390.64042', 'Amount': '500.000', 'Content': '0200970415090220272520240Ppe432198.64042. 202714.NGUYEN THI LAN HANH Quyen gop'}, {'Date': '03/09/2024', 'TransactionID': '5218.45892', 'Amount': '10.000', 'Content': '881384.030924.070324.Ung Ho Nha Nuoc Viet Nam Va Giup do Nguoi dan'}, {'Date': '03/09/2024', 'TransactionID': '5216.65140', 'Amount': '200.000', 'Content': '120167.030924.100642.NGUYEN HOAI NAM ung ho'}, {'Date': '03/09/2024', 'TransactionID': '5219.76834', 'Amount': '300.000', 'Content': '069690.030924.111352.Ung ho dong bao Viet Nam FT24248787369079'}, {'Date': '03/09/2024', 'TransactionID': '5216.79404', 'Amount': '370.000', 'Content': '524035.030924.111445.IBFT TRAN THI MY PHUONG chuyen tien'}, {'Date': '03/09/2024', 'TransactionID': '5212.96110', 'Amount': '100.000', 'Content': '160707.030924.112000.NGUYEN HOAI PHUONG CK BCT TW'}, {'Date': '03/09/2024', 'Tra ...

# %% [markdown]
# # Chuyển về dataframe với 3 page đầu tiên

# %%
# Chuyển đổi danh sách dictionaries thành DataFrame
data_final = pd.DataFrame(cleaned_dictionaries)

# Hiển thị DataFrame
data_final
# Out:
#           Date TransactionID     Amount
# 0   01/09/2024    5213.45946     50.000  \
# 1   01/09/2024    5090.85797     20.000
# 2   01/09/2024    5241.83107     29.000
# 3   01/09/2024    5218.87149      3.000
# 4   01/09/2024    5388.96713      3.000
# 5   01/09/2024    5212.91607      3.000
# 6   01/09/2024    5220.28596      3.000
# 7   01/09/2024    5388.33462      3.000
# 8   01/09/2024    5216.68569      3.000
# 9   01/09/2024    5387.37142      3.000
# 10  01/09/2024    5161.94345     10.000
# 11  01/09/2024    5219.94264      6.000
# 12  01/09/2024    5215.97152      3.000
# 13  01/09/2024    5219.24714     10.000
# 14  02/09/2024    5212.22965     10.000
# 15  02/09/2024    5245.21394     10.000
# 16  02/09/2024    5078.73943     50.000
# 17  02/09/2024     5216.8149      2.000
# 18  02/09/2024    5390.64042    500.000
# 19  03/09/2024    5218.45892     10.000
# 20  03/09/2024    5216.65140    200.000
# 21  03/09/2024    5219.76834    300.000
# 22  03/09/2024    5216.79404    370.000
# 23  03/09/2024    5212.96110    100.000
# 24  03/09/2024    5017.43849      9.000
# 25  03/09/2024    5243.88658     10.000
# 26  03/09/2024    5387.57821    100.000
# 27  03/09/2024    5216.95779     12.000
# 28  04/09/2024    5213.16917     20.000
# 29  04/09/2024    5078.88171     80.000
# 30  04/09/2024    5017.44381  5.000.000
# 31  04/09/2024    5214.46619      6.000
# 32  04/09/2024    5245.19623     10.000
# 33  04/09/2024    5215.70219      6.000
# 34  04/09/2024     5220.4615      3.000
# 35  04/09/2024    5218.21248  1.000.000
# 36  04/09/2024    5390.37909      6.000
# 37  04/09/2024    5215.56651      3.000
# 38  04/09/2024     5218.4587      3.000
# 39  04/09/2024    5212.38625      6.000
# 40  04/09/2024    5213.38757      3.000
# 41  04/09/2024    5215.87518      6.000
# 42  04/09/2024    5214.26135      6.000
# 43  04/09/2024    5213.87095      6.000
# 44  04/09/2024    5245.72042      6.000
# 45  04/09/2024    5245.72528      3.000
# 46  04/09/2024    5219.33442      6.000
# 47  04/09/2024    5387.20559      5.000
# 48  04/09/2024    5216.38958      6.000
#
#                                               Content
# 0                     292976.010924.013647.xin cam on
# 1   VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu 04810007...
# 2   MBVCB.6916176124.CAO VIET TUAN chuyen tien.CT ...
# 3         272986.010924.101858.DO DUC LOI chuyen tien
# 4   020097040509011046122024JDC5013867.96713 .1046...
# 5        529474.010924.112032.BUI VAN DAI chuyen tien
# 6            577301.010924.113215.DO DUC LOI MHS 4242
# 7   020097040509011137472024Y7ZE058213.33462 .1137...
# 8    761664.010924.121847.NGUYEN VAN TUAN chuyen tien
# 9   0200970405090112202020246WVI059470.3714 2.1220...
# 10  PARTNER.DIRECT_DEBITS_VCB.ZLP.ZP6R 34H953F5.20...
# 11  266303.010924.122804.NGUYEN THI MAO Chuyen tie...
# 12    267515.010924.122904.NGUYEN THI MAO Chuyen tien
# 13  018806.010924.213139.chuc mung ngay 29 nuoc co...
# 14  055464.020924.064157.Ung Ho Nha Nuoc Viet Nam ...
# 15  MBVCB.6924605040.gia dinh Dung Thuy Giang chuc...
# 16  MBVCB.6925071164.mung ngay quoc khanh.CT tu 10...
# 17                       524322.020924.175952.2091945
# 18  0200970415090220272520240Ppe432198.64042. 2027...
# 19  881384.030924.070324.Ung Ho Nha Nuoc Viet Nam ...
# 20        120167.030924.100642.NGUYEN HOAI NAM ung ho
# 21  069690.030924.111352.Ung ho dong bao Viet Nam ...
# 22  524035.030924.111445.IBFT TRAN THI MY PHUONG c...
# 23  160707.030924.112000.NGUYEN HOAI PHUONG CK BCT TW
# 24  888828.030924.121121.NGUYEN THI KIEU OANH chuy...
# 25  MBVCB.6934364247.gia dinh Dung Thuy Giang chuc...
# 26  0200970415090316001320248Tkn135640.57821. 1600...
# 27   633739.030924.184314.NGUYEN VAN LINH Chuyen tien
# 28    718788.040924.001536.LE THI MY HANH chuyen tien
# 29  MBVCB.6938069039.kho khan.CT tu 1013662745 toi...
# 30  938529.040924.081441.NGUYEN VAN HUNG FT2424805...
# 31                 268515.040924.081538.Ha Duy Phuong
# 32  MBVCB.6939182690.gia dinh Dung Thuy Giang chuc...
# 33     563774.040924.092651.PHAM THI THAO chuyen tien
# 34  429224.040924.100236.NGUYEN THI NGOC LE chuyen...
# 35  400350.040924.100646.LE THI QUYNH ANH chuyen F...
# 36  020097040509041008052024HEVJ019980.37909 .1007...
# 37       786355.040924.101558.PHAM DUY AN chuyen tien
# 38  535425.040924.102817.NGUYEN THI NGOC LE chuyen...
# 39  589169.040924.104213.NGUYEN DINH CONG Chuyen tien
# 40  615422.040924.104233.NGUYEN THI NGOC LE chuyen...
# 41       731722.040924.110028.LU VAN VIET chuyen tien
# 42   134306.040924.111235.DANG VAN TRUONG chuyen tien
# 43       897356.040924.113216.PHAM VAN TU chuyen tien
# 44  MBVCB.6940967676.Tran thi son 13/02/1981.CT tu...
# 45  MBVCB.6940985087.BUI TIEN DAT chuyen tien.CT t...
# 46  965157.040924.114619.NGUYEN MINH TIEN chuyen tien
# 47  020097040509041212082024EMJ2007202.20559 .1212...
# 48  119629.040924.121848.NGUYEN MINH TIEN chuyen tien
